# %%
import pandas as pd

data = {
    "Order_ID": [
        "ORD001","ORD002","ORD003","ORD004","ORD005",
        "ORD006","ORD007","ORD008","ORD009","ORD010",
        "ORD011","ORD012"
    ],
    "Region": [
        "North","South","West","East","North","West",
        "South","East","West","North","South","West"
    ],
    "Category": [
        "Electronics","Furniture","Electronics","Clothing",
        "Furniture","Electronics","Clothing","Furniture",
        "Electronics","Clothing","Furniture","Electronics"
    ],
    "Sub_Category": [
        "Laptop","Chair","Mobile","Jeans",
        "Table","Laptop","Shirt","Sofa",
        "Headphones","Jacket","Chair","Mobile"
    ],
    "Sales": [
        85000,22000,56000,9000,
        18000,92000,7000,26000,
        31000,12000,17000,65000
    ],
    "Profit": [
        18000,2500,9000,1500,
        1800,22000,1200,3000,
        4000,1800,1500,11000
    ],
    "Discount": [
        5,20,10,30,
        25,0,15,10,
        5,20,30,10
    ],
    "Quantity": [
        2,4,3,5,
        2,2,4,2,
        5,3,2,3
    ],
    "Customer_Age": [
        28,42,35,24,
        39,31,27,48,
        29,36,51,33
    ],
    "Customer_Gender": [
        "Male","Female","Male","Female",
        "Female","Male","Female","Male",
        "Female","Male","Female","Male"
    ],
    "Payment_Mode": [
        "Card","UPI","Card","Cash",
        "UPI","Card","UPI","Cash",
        "UPI","Cash","UPI","Card"
    ]
}

# %%
# Display first few rows
df = pd.DataFrame(data)
df
# Out:
#    Order_ID Region     Category Sub_Category  Sales  Profit  Discount  \
# 0    ORD001  North  Electronics       Laptop  85000   18000         5
# 1    ORD002  South    Furniture        Chair  22000    2500        20
# 2    ORD003   West  Electronics       Mobile  56000    9000        10
# 3    ORD004   East     Clothing        Jeans   9000    1500        30
# 4    ORD005  North    Furniture        Table  18000    1800        25
# 5    ORD006   West  Electronics       Laptop  92000   22000         0
# 6    ORD007  South     Clothing        Shirt   7000    1200        15
# 7    ORD008   East    Furniture         Sofa  26000    3000        10
# 8    ORD009   West  Electronics   Headphones  31000    4000         5
# 9    ORD010  North     Clothing       Jacket  12000    1800        20
# 10   ORD011  South    Furniture        Chair  17000    1500        30
# 11   ORD012   West  Electronics       Mobile  65000   11000        10
#
#     Quantity  Customer_Age Customer_Gender Payment_Mode
# ...

# %%
# Q1. Which product category generates the highest total sales?

# Hint: Think about a chart that compares values across categories.

# Find insights:

# Which category performs best?
# Is the difference significant?
# Which category may need improvement?

# %%
# Q2. Does giving higher discounts always lead to higher sales?

# Hint: Use a chart that shows the relationship between two numerical variables.

# Find insights:

# Is there a positive or negative trend?
# Are there any outliers?
# Would increasing discounts always be a good business decision?

# %%
# Q3. Which region is the most profitable?

# Hint: Compare profit across different regions using an appropriate categorical chart.

# Find insights:

# Which region should the company invest in?
# Which region is underperforming?
# Are sales and profit telling the same story?

# %%
# Q4. How are customer ages distributed? Are there any unusual values?

# Hint: First think of a chart that shows the distribution of a numerical variable. Then think of another chart that helps identify outliers.

# Find insights:

# Which age group is most common?
# Is the data skewed?
# Are there any outliers that need investigation?

# %%
# Q5. Which payment mode is most popular, and does customer gender influence payment preference?

# Hint: Start with a chart for counting categories. Then think of a chart that compares counts across two categorical variables.

# Find insights:

# Which payment mode is preferred overall?
# Do males and females show different payment preferences?
# What recommendation would you give to the business based on this?
