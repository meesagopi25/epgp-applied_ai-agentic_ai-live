# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# # Variables and data types

# %%
# python uses indentationt o defien block of code
age = 21
if age >= 18:
  print("You are an adult")
else:
  print("You are a minor")
# variable is the name that refers to a value
employee_name = "Gopi"
course_name = "EPGP in Applied AI and Agentic AI by IIITB upGrad"
is_registered = True
name, age, city = "Gopi",44,"Bangalore"
print(name, age, city)
print(employee_name)
print(course_name)
print(is_registered)

course_fee = "500"
discount_percent = 12.4
discount_amount = float(course_fee) * discount_percent / 100
print(discount_amount)
print("type of discount_amount:",type(discount_amount))
print(type(course_fee))
print(type(discount_percent))
print(type(is_registered))
print(type(employee_name))
result = None
print(type(result))

x = input("Enter the value of x")
print(x)
# python is dynamically typed language
# it means that the type of a variable is determined at runtime
# and can change during the execution of the program
# you can't start variable with a digit
# you can't use special characters other than underscore
# you can't use reserved keywords as variable names
# you can't use spaces in variable names
# you can't use hyphens in variable names
# you can't use periods in variable names
# you can't use backticks in variable names
# you can't use single quotes in variable names
# you can't use double quotes in variable names
# you can't use backslashes in variable names
# you can't use forward slashes in variable names
# you can't use colons in variable names
# you can't use semicolons in variable names
# you can't use asterisks in variable names
# you can't use ampersands in variable names
# you can't use vertical bars in variable names
# you can't use tildes in variable names
# you can't use brackets in variable names
# you can't use braces in variable names
# you can't use parentheses in variable names
# you can't use square brackets in variable names
# you can't use curly braces in variable names
# you can't use angle brackets in variable names
# you can't use quotes in variable names
# you can't use backticks in variable names
# you can't use backslashes in variable names
# you can't use forward slashes in variable names
# you can't use colons in variable names
# you can't use semicolons in variable names
# you can't use asterisks in variable names
# Out:
# You are an adult
# Gopi 44 Bangalore
# Gopi
# EPGP in Applied AI and Agentic AI by IIITB upGrad
# True
# 62.0
# type of discount_amount: <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# <class 'NoneType'>
# Enter teh value of x 12
# 12

# %% [markdown]
# # Operator and decesion making

# %%
a = 2
b = 3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)

if a == b:
    print("a is equal to b")
else:
    print("a is not equal to b")

age = 21
had_voted = True
print(age >= 18 and had_voted)
print(age >= 18 or had_voted)
print(not age >= 18)
print(not had_voted)
print(age >= 18 and not had_voted)
# Out:
# 5
# -1
# 6
# 0.6666666666666666
# 2
# 8
# a is not equal to b
# True
# True
# False
# False
# False
