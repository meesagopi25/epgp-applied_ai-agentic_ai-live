# %%
# NumPy : numerical python, array, mathematical operation!
# pythonic data types : list tuples sets dict
# numpy : array

# %%
# Why Pandas?

# How many of you have used excel? Excel has limitation when data is large.

# Suppose :
# 50 million customers
# 100 csv files
# Need some automation

# Using excel in this scenario becomes challenging.

# Pandas allows us to :
# 1. Read data
# 2. Clean data
# 3. Transform data
# 4. Analyse data
# 5. Export results

# Think of Pandas - Excel of Steroids using python!

# %%
# What is structured data?
# Rows and columns (Tabular Data)

# %%
import numpy  as np
import pandas as pd

# %%
# 1. Series : One column!
age = pd.Series([20,22,24,26,28,30,32])
print(age)
# Out:
# 0    20
# 1    22
# 2    24
# 3    26
# 4    28
# 5    30
# 6    32
# dtype: int64

# %%
# A series has 2 things : i) Index ii) Values

# %%
# 2. Dataframe : Multiple Series together!
students = pd.DataFrame(
    {
        'Name' : ['a','b','c','d','e'],
        'Age'  : [20,30,40,50,60],
        'Marks': [80,70,60,50,40]
    }
)

# %%
students
# Out:
#   Name  Age  Marks
# 0    a   20     80
# 1    b   30     70
# 2    c   40     60
# 3    d   50     50
# 4    e   60     40

# %%
type(students)
# Out:
# pandas.core.frame.DataFrame

# %%
students['Name'] # fetch name column from a student df
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# Name: Name, dtype: object

# %%
type(students['Name'])
# Out:
# pandas.core.series.Series

# %%
students['Name'].values
# Out:
# array(['a', 'b', 'c', 'd', 'e'], dtype=object)

# %%
sales = pd.DataFrame({
    "OrderID":[101,102,103,104,105,106],
    "Customer":["Sankara","Priya","Rohit","Sneha","Rahul","Neha"],
    "City":["Delhi","Mumbai","Delhi","Pune","Delhi","Mumbai"],
    "Category":["Laptop","Phone","Tablet","Laptop","Phone","Tablet"],
    "Quantity":[2,1,3,1,2,5],
    "Price":[75000,45000,30000,80000,50000,25000]
})

sales
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 0      101  Sankara   Delhi   Laptop         2  75000
# 1      102    Priya  Mumbai    Phone         1  45000
# 2      103    Rohit   Delhi   Tablet         3  30000
# 3      104    Sneha    Pune   Laptop         1  80000
# 4      105    Rahul   Delhi    Phone         2  50000
# 5      106     Neha  Mumbai   Tablet         5  25000

# %%
sales.head() # default : first 5 rows
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 0      101  Sankara   Delhi   Laptop         2  75000
# 1      102    Priya  Mumbai    Phone         1  45000
# 2      103    Rohit   Delhi   Tablet         3  30000
# 3      104    Sneha    Pune   Laptop         1  80000
# 4      105    Rahul   Delhi    Phone         2  50000

# %%
sales.head(1) # first row
# Out:
#    OrderID Customer   City Category  Quantity  Price
# 0      101  Sankara  Delhi   Laptop         2  75000

# %%
sales.tail() # default : last 5 rows
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 1      102    Priya  Mumbai    Phone         1  45000
# 2      103    Rohit   Delhi   Tablet         3  30000
# 3      104    Sneha    Pune   Laptop         1  80000
# 4      105    Rahul   Delhi    Phone         2  50000
# 5      106     Neha  Mumbai   Tablet         5  25000

# %%
sales.tail(1) # last row in the output
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 5      106     Neha  Mumbai   Tablet         5  25000

# %%
sales.shape
# rows, columns
# Out:
# (6, 6)

# %%
sales.columns
# Out:
# Index(['OrderID', 'Customer', 'City', 'Category', 'Quantity', 'Price'], dtype='object')

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
sales
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 0      101  Sankara   Delhi   Laptop         2  75000
# 1      102    Priya  Mumbai    Phone         1  45000
# 2      103    Rohit   Delhi   Tablet         3  30000
# 3      104    Sneha    Pune   Laptop         1  80000
# 4      105    Rahul   Delhi    Phone         2  50000
# 5      106     Neha  Mumbai   Tablet         5  25000

# %%
sales.info()
# Generate Information for the sales df
# info() is one of the first commands you run when opening an unknown dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   OrderID   6 non-null      int64
#  1   Customer  6 non-null      object
#  2   City      6 non-null      object
#  3   Category  6 non-null      object
#  4   Quantity  6 non-null      int64
#  5   Price     6 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 420.0+ bytes

# %%
sales
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 0      101  Sankara   Delhi   Laptop         2  75000
# 1      102    Priya  Mumbai    Phone         1  45000
# 2      103    Rohit   Delhi   Tablet         3  30000
# 3      104    Sneha    Pune   Laptop         1  80000
# 4      105    Rahul   Delhi    Phone         2  50000
# 5      106     Neha  Mumbai   Tablet         5  25000

# %%
sales.describe()
# stats about numerical data
# Out:
#           OrderID  Quantity         Price
# count    6.000000  6.000000      6.000000
# mean   103.500000  2.333333  50833.333333
# std      1.870829  1.505545  22675.243475
# min    101.000000  1.000000  25000.000000
# 25%    102.250000  1.250000  33750.000000
# 50%    103.500000  2.000000  47500.000000
# 75%    104.750000  2.750000  68750.000000
# max    106.000000  5.000000  80000.000000

# %%
sales
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 0      101  Sankara   Delhi   Laptop         2  75000
# 1      102    Priya  Mumbai    Phone         1  45000
# 2      103    Rohit   Delhi   Tablet         3  30000
# 3      104    Sneha    Pune   Laptop         1  80000
# 4      105    Rahul   Delhi    Phone         2  50000
# 5      106     Neha  Mumbai   Tablet         5  25000

# %%
# 1 column :
sales['OrderID']
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# 5    106
# Name: OrderID, dtype: int64

# %%
# 1 + col :
sales[['OrderID','City']]
# Out:
#    OrderID    City
# 0      101   Delhi
# 1      102  Mumbai
# 2      103   Delhi
# 3      104    Pune
# 4      105   Delhi
# 5      106  Mumbai

# %%
sales[['OrderID','City','Price']]
# Out:
#    OrderID    City  Price
# 0      101   Delhi  75000
# 1      102  Mumbai  45000
# 2      103   Delhi  30000
# 3      104    Pune  80000
# 4      105   Delhi  50000
# 5      106  Mumbai  25000

# %%
sales.dtypes
# column name and their data types
# Out:
# OrderID      int64
# Customer    object
# City        object
# Category    object
# Quantity     int64
# Price        int64
# dtype: object

# %%
# Indexing and Slicing in Pandas DF :

# %%
# i. iloc
# ii. loc

# %%
# 1. iloc : integer based indexing!

# %%
sales
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 0      101  Sankara   Delhi   Laptop         2  75000
# 1      102    Priya  Mumbai    Phone         1  45000
# 2      103    Rohit   Delhi   Tablet         3  30000
# 3      104    Sneha    Pune   Laptop         1  80000
# 4      105    Rahul   Delhi    Phone         2  50000
# 5      106     Neha  Mumbai   Tablet         5  25000

# %%
print(sales.iloc[0,0]) # 0th row, 0th col index : 1st row, 1st col
# Out:
# 101

# %%
print(sales.iloc[2,3]) # 2nd row, 3rd col index : 3rd row, 4th col
# Out:
# Tablet

# %%
# 2. loc : label based indexing

# %%
sales
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 0      101  Sankara   Delhi   Laptop         2  75000
# 1      102    Priya  Mumbai    Phone         1  45000
# 2      103    Rohit   Delhi   Tablet         3  30000
# 3      104    Sneha    Pune   Laptop         1  80000
# 4      105    Rahul   Delhi    Phone         2  50000
# 5      106     Neha  Mumbai   Tablet         5  25000

# %%
sales.loc[0,['Customer','Price']]
# Out:
# Customer    Sankara
# Price         75000
# Name: 0, dtype: object

# %%
sales
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 0      101  Sankara   Delhi   Laptop         2  75000
# 1      102    Priya  Mumbai    Phone         1  45000
# 2      103    Rohit   Delhi   Tablet         3  30000
# 3      104    Sneha    Pune   Laptop         1  80000
# 4      105    Rahul   Delhi    Phone         2  50000
# 5      106     Neha  Mumbai   Tablet         5  25000

# %%
# Filter on laptop category
sales['Category'] == 'Laptop'
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# Name: Category, dtype: bool

# %%
sales[sales['Category'] == 'Laptop']
# Out:
#    OrderID Customer   City Category  Quantity  Price
# 0      101  Sankara  Delhi   Laptop         2  75000
# 3      104    Sneha   Pune   Laptop         1  80000

# %%
sales[sales['Price'] < 50000]
# sales[] => filter condition within brackers.
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 1      102    Priya  Mumbai    Phone         1  45000
# 2      103    Rohit   Delhi   Tablet         3  30000
# 5      106     Neha  Mumbai   Tablet         5  25000

# %%
# And clause :
sales[
    (sales["City"]=="Delhi") &
    (sales["Price"]>40000)

]
# Out:
#    OrderID Customer   City Category  Quantity  Price
# 0      101  Sankara  Delhi   Laptop         2  75000
# 4      105    Rahul  Delhi    Phone         2  50000

# %%
# & : and
# | : or

# %%
# Question 1
# Display only Customer and Category.

# Question 2
# Find all Phone orders.

# Question 3
# Find all orders from Delhi.

# Question 4
# Display the first three rows.

# Question 5
# How many rows and columns are present?

# %%
# Question 1
# Display only Customer and Category.
sales[['Customer','Category']]
# Out:
#   Customer Category
# 0  Sankara   Laptop
# 1    Priya    Phone
# 2    Rohit   Tablet
# 3    Sneha   Laptop
# 4    Rahul    Phone
# 5     Neha   Tablet

# %%
sales
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 0      101  Sankara   Delhi   Laptop         2  75000
# 1      102    Priya  Mumbai    Phone         1  45000
# 2      103    Rohit   Delhi   Tablet         3  30000
# 3      104    Sneha    Pune   Laptop         1  80000
# 4      105    Rahul   Delhi    Phone         2  50000
# 5      106     Neha  Mumbai   Tablet         5  25000

# %%
# Question 2
# Find all Phone orders.
sales[sales['Category'] == 'Phone']
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 1      102    Priya  Mumbai    Phone         1  45000
# 4      105    Rahul   Delhi    Phone         2  50000

# %%
# Question 3
# Find all orders from Delhi.
sales[sales['City'] == 'Delhi']
# Out:
#    OrderID Customer   City Category  Quantity  Price
# 0      101  Sankara  Delhi   Laptop         2  75000
# 2      103    Rohit  Delhi   Tablet         3  30000
# 4      105    Rahul  Delhi    Phone         2  50000

# %%
# Question 4
# Display the first three rows.
sales.head(4)
# Out:
#    OrderID Customer    City Category  Quantity  Price
# 0      101  Sankara   Delhi   Laptop         2  75000
# 1      102    Priya  Mumbai    Phone         1  45000
# 2      103    Rohit   Delhi   Tablet         3  30000
# 3      104    Sneha    Pune   Laptop         1  80000

# %%
# Question 5
# How many rows and columns are present?
sales.shape
sales.dtypes
type(sales)
#sales.ndim
#sales.axes
#sales.columns
#sales.index
#sales.values
# sales.describe()
sales.head()
sales.tail()
sales.iloc[2,3]
# Out:
# 'Tablet'
